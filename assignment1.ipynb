# %%
print("Hello","Ankit",sep=" - ")
print("Next line")
# Out:
# Hello - Ankit
# Next line

# %%
print('Hello',"Python","4 June 2026",sep=" - ",end="\n" "Next line")
# Out:
# Hello - Python - 4 June 2026
# next line

# %%
Name = input("Enter your name: ")
print("Hello," + Name + "!")
