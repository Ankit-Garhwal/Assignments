# %%
Name = input("Name:")
Class = input("Class: ")
sub1 = float(input("Enter marks for subject 1: "))
sub2 = float(input("Enter marks for subject 2: "))
sub3 = float(input("Enter marks for subject 3: "))
sub4 = float(input("Enter marks for subject 4: "))
sub5 = float(input("Enter marks for subject 5: "))
Sum = sub1 + sub2 + sub3 + sub4 + sub5
Percentage = (Sum / 500) * 100
print("Name:", Name)
print("Class:", Class)
print("Total Marks:", Sum)
print("Percentage:", Percentage, "%")
# Out:
# Name:  Ankit
# Class:  12
# Total Marks:  250.0
# Percentage:  50.0 %

# %%
str1 = "Assignment"
str2 = "Second"
str3 = str1 + " " + str2
print(str3)
print(str3.lower())
print(str3.upper())
print(str3.title())
print(str3.swapcase())
print(str3.capitalize())
print(str3.casefold())
print(str3.center(30))
print(str3.count("s"))
print(str3.endswith("t"))
print(str3.find("S"))
print(str3.isalnum())
print(str3.isdigit())
print(str3.isnumeric())
print(str3.isspace())
print(str3.replace("Second", "2nd"))
# Out:
# Assignment Second
# assignment second
# ASSIGNMENT SECOND
# Assignment Second
# aSSIGNMENT sECOND
# Assignment second
# assignment second
#       Assignment Second
# 2
# False
# 11
# False
# False
# False
# False
# Assignment 2nd

# %%
num1 = 10
print("The value of num1 is:", num1)
num1 += 3
print("The updated value of num1 is:", num1)
num1 -=3
print("The updated value of num1 is:", num1)
num1 *= 3
print("The updated value of num1 is:", num1)
num1 /= 3
print("The updated value of num1 is:", num1)
# Out:
# The value of num1 is: 10
# The updated value of num1 is: 13
# The updated value of num1 is: 10
# The updated value of num1 is: 30
# The updated value of num1 is: 10.0
